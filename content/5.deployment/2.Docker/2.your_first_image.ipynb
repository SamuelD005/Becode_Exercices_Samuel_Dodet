# %% [markdown]
# # Your first image!
#
# Ok now that you understand what Docker is and why use it (at least I hope, if not you will soon!), it is time to get more technical.
#
# ## Goal
# In this module we will learn:
# * What is the **concrete** difference between an **image** and a **container**
# * How to create an image?
# * What is a Dockerfile and how to use it?
# * How to create a container out of an image?
#
# And we will run our very first container based on our very first image!
#
# ![do-it](./assets/do-it.gif)

# %% [markdown]
# ## Installation
# First things first, we need to install Docker.
#
# You just have to follow [Docker's well made documentation](https://docs.docker.com/engine/install/ubuntu/).
#
# If you're running Windows or Mac -> https://docs.docker.com/engine/install/
#
# By default, Docker will need to use `sudo` each time. Let's change that:
# ```bash
# sudo gpasswd -a $USER docker
# ```
#
# You will need to log-out before it applies the changes.
#
# ## How do we create an image
# In order to create images (or import them), we could:
#
# ### Go to [Docker Hub](https://hub.docker.com/)
#
# which is like GitHub for Docker images.
# You need an image with a SQL DB in it? [There is one](https://hub.docker.com/r/mysalt/mysql).
# You need an image with python 3.6? [There is one](https://hub.docker.com/r/silverlogic/python3.6).
# And a lot of other images!
#
# ### Create your own docker file!
#
# In many cases, we will want to create our own images, with our own files and our own script.
# In order to do that we will create what we call a `Dockerfile`.
#
# This is just a file that is named `Dockerfile` and that contains a script that Docker can understand.
# Based on that, it will create an image.
#
# ## Let's create our image
# It's time! So we will create a `Dockerfile` and we will use a python image as base. It means that we start from an existing image to build our own.
# So we don't have to start from scratch each time.
#
# In this file we will add a line to tell Docker that we want to start from the official Python 3.7 image.
#
# The `FROM` keyword is used to tell Docker which base image we will use.
#
# ```Dockerfile
# FROM python:3.7
# ```
#
# Now let's add another line to copy a file. In the folder you're in, there is a file named `hello_world.py`. This file contains a single line:
#
# ```python
# print("Hello world!")
# ```
#
# We will create folder called `app` and put our file in it. As the python image is built on top of Ubuntu, we can use all the commands that work in Ubuntu.
#
# Let's see some useful keywords that can be used in a Dockerfile:
# * The `RUN` keyword can be uses to run a command on the system.
# * The `COPY` keyword can be used to copy a file.
# * The `WORKDIR` keyword can be used to define the path where all the commands will be run starting after it.
# * The `CMD` keyword can be used to define the command that the container will run when it will be launched.
#
#
# ```Dockerfile
# RUN mkdir /app
# RUN mkdir /app/code
# COPY code/hello_world.py /app/code/hello_world.py
# WORKDIR /app
# CMD ["python", "code/hello_world.py"]
# ```
#
# ## Let's build our image!
# Now we're ready to create our first image! Exciting right?
#
# We say that we `build` our image. That's the term.
#
# The command is: `docker build . -t hello`
#
# * `docker` to specify that we use docker
# * `build` to specify that we want to create an image
# * `.` to specify that the Dockerfile is in the current directory
# * `-t hello` to add a name to our image. If we don't do that we will need to use the ID that docker defines for us and it's not easy to remember.
#
# I already created the Dockerfile for you. Have a look on it!

# %%
# !docker build . -t hello
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (1/2)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.0s
# [+] Building 0.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.1s
# [+] Building 0.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.3s
# [+] Building 0.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.4s
# [+] Building 0.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.6s
# [+] Building 1.0s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.7s
# [+] Building 1.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.9s
# [+] Building 1.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.1s
# [+] Building 1.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.2s
# [+] Building 1.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.4s
# [+] Building 1.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.5s
# [+] Building 1.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.7s
# [+] Building 2.0s (3/3)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
# [+] Building 2.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.1s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.1s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4 0B / 10.00MB  0.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.2s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.2s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4 0B / 10.00MB  0.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.2s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.4s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.4s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4 0B / 10.00MB  0.4s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.5s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.5s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4 0B / 10.00MB  0.5s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.6s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.6s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 1.05MB / 10.00MB  0.6s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.6s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.8s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.8s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 1.05MB / 10.00MB  0.8s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 2.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.9s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  0.9s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 1.05MB / 10.00MB  0.9s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  0.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.0s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.0s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 1.05MB / 10.00MB  1.0s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.1s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.1s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 1.05MB / 10.00MB  1.1s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.3s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.3s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 2.10MB / 10.00MB  1.3s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.4s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.4s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 2.10MB / 10.00MB  1.4s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.6s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.6s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 2.10MB / 10.00MB  1.6s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.6s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.7s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.7s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 2.10MB / 10.00MB  1.7s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e2 0B / 50.43MB  1.7s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 3.9s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  1.8s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  1.8s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 2.10MB / 10.00MB  1.8s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 1.05MB / 50.43MB  1.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.0s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  2.0s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 3.15MB / 10.00MB  2.0s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 1.05MB / 50.43MB  2.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.2s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.1s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  2.1s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 3.15MB / 10.00MB  2.1s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 1.05MB / 50.43MB  2.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.3s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d 0B / 7.83MB  2.3s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 3.15MB / 10.00MB  2.3s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 1.05MB / 50.43MB  2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.4s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  2.4s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 3.15MB / 10.00MB  2.4s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 1.05MB / 50.43MB  2.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.5s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  2.5s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 3.15MB / 10.00MB  2.5s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 2.10MB / 50.43MB  2.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.7s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  2.7s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  2.7s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 2.10MB / 50.43MB  2.7s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 4.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.8s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  2.8s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  2.8s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 2.10MB / 50.43MB  2.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  2.9s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  2.9s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  2.9s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 2.10MB / 50.43MB  2.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.1s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.1s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.1s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 2.49MB / 50.43MB  3.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.2s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.2s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 3.15MB / 50.43MB  3.2s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.4s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.4s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.4s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 3.15MB / 50.43MB  3.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.5s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.5s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.5s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 3.15MB / 50.43MB  3.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.6s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.6s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.6s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.6s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 3.15MB / 50.43MB  3.6s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.7s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.7s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.7s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 4.19MB / 10.00MB  3.7s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 4.19MB / 50.43MB  3.7s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 5.8s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.8s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.8s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 5.24MB / 10.00MB  3.8s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 4.19MB / 50.43MB  3.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 6.0s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  3.9s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  3.9s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 5.24MB / 10.00MB  3.9s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 4.19MB / 50.43MB  3.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 6.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  4.1s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  4.1s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 5.24MB / 10.00MB  4.1s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 4.19MB / 50.43MB  4.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 6.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  4.2s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836 1.05MB / 7.83MB  4.2s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e 5.24MB / 10.00MB  4.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be039090 5.24MB / 50.43MB  4.2s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
# [+] Building 6.4s (4/9)
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  4.4s
# ...
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf 10.00MB / 10.00MB  13.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
# [+] Building 155.1s (6/9)
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf 10.00MB / 10.00MB  13.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.1s
# [+] Building 155.2s (6/9)
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf 10.00MB / 10.00MB  13.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.3s
# [+] Building 155.4s (6/9)
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf 10.00MB / 10.00MB  13.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.4s
# [+] Building 155.5s (9/9)
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.5s
#  => [4/5] COPY code/hello_world.py /app/code/hello_world.py                0.0s
#  => [5/5] WORKDIR /app                                                     0.0s
# [+] Building 155.6s (9/10)
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.5s
#  => [4/5] COPY code/hello_world.py /app/code/hello_world.py                0.0s
#  => [5/5] WORKDIR /app                                                     0.0s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 155.7s (9/10)
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.5s
#  => [4/5] COPY code/hello_world.py /app/code/hello_world.py                0.0s
#  => [5/5] WORKDIR /app                                                     0.0s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.3s
# [+] Building 155.8s (10/10) FINISHED
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 195B                                       0.1s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e9  152.2s
#  => => resolve docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => => sha256:b2f481b62ddf1689ce2a7aa392edcce8a297ab724c5 2.22kB / 2.22kB  0.0s
#  => => sha256:9b5e75b69a4fd4c3fc674a62857b855396f3e9d71b5 9.04kB / 9.04kB  0.0s
#  => => sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f83 7.83MB / 7.83MB  18.6s
#  => => sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf 10.00MB / 10.00MB  13.2s
#  => => sha256:2418d2580b0696cfe3e924ada34478dc30e5dbdf2cf 1.86kB / 1.86kB  0.0s
#  => => sha256:d960726af2bec62a87ceb07182f7b94c47be0390 50.43MB / 50.43MB  35.2s
#  => => sha256:65d943ee54c1fa196b54ab9a6673174c66eea04c 51.84MB / 51.84MB  71.8s
#  => => sha256:532f6f7237092ebd79f21ccd3cf050138b31a 192.35MB / 192.35MB  135.7s
#  => => sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085 6.15MB / 6.15MB  41.2s
#  => => extracting sha256:d960726af2bec62a87ceb07182f7b94c47be03909077e23d  4.3s
#  => => extracting sha256:e8d62473a22dec9ffef056b2017968a9dc484c8f836fb6d7  0.5s
#  => => extracting sha256:8962bc0fad55b13afedfeb6ad5cb06fd065461cf3e1ae4e7  0.6s
#  => => sha256:ba365db42d143222de2a48c0c47039747bebe1a7 16.33MB / 16.33MB  55.9s
#  => => sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe 232B / 232B  56.6s
#  => => sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097 2.35MB / 2.35MB  62.4s
#  => => extracting sha256:65d943ee54c1fa196b54ab9a6673174c66eea04cfa1a4ac5  5.8s
#  => => extracting sha256:532f6f7237092ebd79f21ccd3cf050138b31abeed1b29ba  13.2s
#  => => extracting sha256:1334e0fe2851ea7f3d2509a3907312a665d7c6b085e1f067  0.6s
#  => => extracting sha256:ba365db42d143222de2a48c0c47039747bebe1a7858712d0  1.2s
#  => => extracting sha256:9c5512e22a8630d57cea37ba33500c8a84b79ea18af7fe85  0.0s
#  => => extracting sha256:9b39d3d20df6ad37460b111e70cb48153be0c4c097affc63  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 95B                                           0.0s
#  => [2/5] RUN mkdir /app                                                   0.7s
#  => [3/5] RUN mkdir /app/code                                              0.5s
#  => [4/5] COPY code/hello_world.py /app/code/hello_world.py                0.0s
#  => [5/5] WORKDIR /app                                                     0.0s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
#  => => writing image sha256:39e0dac9ef449325a59a09e50265f665c43bbbf56485c  0.0s
#  => => naming to docker.io/library/hello                                   0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them

# %% [markdown]
# As you can see, our image has been successfully built!
#
# If you look at the last line of the output, you see:
#
# ```
# Successfully tagged hello:latest
# ```
#
# Our image has been tagged with `hello:latest`. As we didn't define any tag at the end of our image name, `latest` will be added by docker.
# If we make changes in our image and re-build it, a new image will be created with the tag `latest` and our old image will no longer have it.
# It's useful when you want to use the most recent version of your image.
#
# We can also add our own tags as follows

# %%
# !docker build . -t another_image:v1.0
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context:                                               0.0s
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.0s
# [+] Building 0.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.2s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.3s
# [+] Building 0.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.5s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.6s
# [+] Building 1.0s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.8s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              0.9s
# [+] Building 1.3s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.1s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.2s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.4s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.5s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.9s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.1s (3/4)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.8s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 2.2s (11/11) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.7              1.9s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [1/5] FROM docker.io/library/python:3.7@sha256:2418d2580b0696cfe3e924  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 64B                                           0.0s
#  => CACHED [2/5] RUN mkdir /app                                            0.0s
#  => CACHED [3/5] RUN mkdir /app/code                                       0.0s
#  => CACHED [4/5] COPY code/hello_world.py /app/code/hello_world.py         0.0s
#  => CACHED [5/5] WORKDIR /app                                              0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:39e0dac9ef449325a59a09e50265f665c43bbbf56485c  0.0s
#  => => naming to docker.io/library/another_image:v1.0                      0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them

# %% [markdown]
# If we try to list all of our images, we will see that we have 3 images.
#
# * One `hello` with the tag `latest`
# * One `hello` with the tag `v1.0`
# * One `python` with the tag `3.7` *(that's the one we used as base image)*
#
# We can see it with:
#
# ```bash
# docker image ls
# ```

# %%
# !docker image ls
# Out:
# REPOSITORY          TAG       IMAGE ID       CREATED              SIZE
# another_image       v1.0      39e0dac9ef44   About a minute ago   877MB
# hello               latest    39e0dac9ef44   About a minute ago   877MB
# docker101tutorial   latest    9dd5ef0fd7e1   6 minutes ago        28MB
# alpine/git          latest    b8f176fa3f0d   3 weeks ago          25.1MB

# %% [markdown]
# ## Manage images
# As you can see images take a lot of place on you hard drive! And the more complex your images are and the more dependencies they have, the bigger they will be.
#
# It rapidly become a pain...
#
# Thankfully, we can remove the one that we don't use anymore with the command:
#
# ```bash
# docker image rm <IMAGE_ID>
# ````
# As we see in the `docker image ls` output, each image has an ID. We will use that to remove them. Let's say we want to remove our `hello:v1.0` image.
# ```
# hello               latest              8f7ca704c0a8        7 minutes ago       876MB
# ```
# Here the ID is `8f7ca704c0a8`. But here multiple images have the same ID. That's because multiples images you the same image.
#
# Confused? It's because Docker is really smart! We tried to create multiple images based on the same Dockerfile, and there were no changes between the creation of the first image and the last one. Neither in the files, nor in the Dockerfile. So Docker knows that it doesn't have to create multiple images! It creates and 'links' it to other tags.
#
# So if I try to delete with the ID it will give me a warning and not do it. Because multiple tags are linked to the same image.
#
# So instead of using IDs we will use tags.

# %%
# !docker image rm hello:v1.0
# Out:
# Untagged: hello:v1.0

# %% [markdown]
# The tag has been removed!

# %%
# !docker image ls
# Out:
# REPOSITORY          TAG                 IMAGE ID            CREATED             SIZE
# hello               latest              8f7ca704c0a8        21 minutes ago      876MB
# python              3.7                 2b00bba7acbb        2 days ago          876MB

# %% [markdown]
# ## Run it
# Perfect! You understand what an image is now! Let's run it.
#
# When we will run the image, Docker will create a `container`, an instance of the image and it will execute the command we added after the `CMD` keyword.
#
# We will do it with the command:
# ```bash
# docker run -t hello:latest
# ```
#
# * `run` is to tell to docker to create a container.
# * `-t hello:latest` is to specify which image it should use to create and run the `container`
#
# If you don't put `:<YOUR_TAG>` docker will add `:latest` by default.

# %%
# !docker run -t hello
# Out:
# Hello world!

# %% [markdown]
# Our container successfully ran. We can see that it printed 'Hello world' as asked.
#
# Ok. So we created a container and we ran it. Can we see it stored somewhere?
#
# Let's try with `docker container ls` maybe?

# %%
# !docker container ls
# Out:
# CONTAINER ID        IMAGE               COMMAND             CREATED             STATUS              PORTS               NAMES

# %% [markdown]
# Damn it, the command seems to be right but there is nothing here!
# Well, `docker container ls` only show running containers. And this one is not running anymore because it completed the task we asked him to do!
#
# So if we want to see all the container, including the stopped one, we can do:
# ```bash
# docker container ls -a
# ```

# %%
# !docker container ls -a
# Out:
# CONTAINER ID        IMAGE               COMMAND                  CREATED             STATUS                      PORTS               NAMES
# cd585b842f8b        hello               "python hello_world.…"   55 minutes ago      Exited (0) 55 minutes ago                       confident_agnesi

# %% [markdown]
# Ok good! We can of course remove it with:
#
# ```bash
# docker contaier rm <CONTAINER_ID>
# ```
#
# So in this case `cd585b842f8b`

# %%
# !docker container rm cd585b842f8b
# Out:
# cd585b842f8b

# %% [markdown]
# It worked!
#
# ## Conclusion
# Great! You now have a complete understanding of images and containers.
#
# In the next module, we will dive deeper into the container and see what we can do with them.
#
# ![We will have so much fun!](./assets/have-fun.gif)
